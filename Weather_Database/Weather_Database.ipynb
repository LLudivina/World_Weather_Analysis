# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#The zip object packs each pair of lats and lngs having the same index in 
#their respective array into a tuple. If there are 1,500 latitudes and 
#longitudes, there will be 1,500 tuples of paired latitudes and longitudes,
#where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 782

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests
import json

# Import the OpenWeatherMap's API key
from config import weather_api_key

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Assemble the OpenWeatherMap's API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_url = url + "&q=" + "poway"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -117.0359, 'lat': 32.9628},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 62.47,
#   'feels_like': 61.43,
#   'temp_min': 55.2,
#   'temp_max': 68.76,
#   'pressure': 1014,
#   'humidity': 64},
#  'visibility': 10000,
#  'wind': {'speed': 8.05, 'deg': 210},
#  'clouds': {'all': 0},
#  'dt': 1672182869,
#  'sys': {'type': 2,
#   'id': 2016735,
#   'country': 'US',
#   'sunrise': 1672152577,
#   'sunset': 1672188523},
#  'timezone': -28800,
#  'id': 5384690,
#  'name': 'Poway',
#  'cod': 200}

# %%
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_description = city_weather["weather"][0]["description"]
print(city_lat)
print(city_lng)
print(city_max_temp)
print(city_humidity)
print(city_clouds)
print(city_wind)
print(city_country)
print(city_description)
# Out:
# 57.0531
# -135.33
# 39.09
# 87
# 100
# 4.61
# US
# light rain

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval")
print("-")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          })
                       
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-")
print("Data Retrieval Complete")
print("-")
# Out:
# Beginning Data Retrieval
# -
# Processing Record 1 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 1 | ahipara
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | pringsewu
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | labuan
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | boa vista
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | mali
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | waterloo
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | velden am worthersee
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | evensk
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | zhizdra
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | trinidad
# Processing Record 32 of Set 1 | serebryansk
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | kitimat
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | kimparana
# Processing Record 38 of Set 1 | honiara
# Processing Record 39 of Set 1 | baghdad
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | haukipudas
# Processing Record 42 of Set 1 | kui buri
# Processing Record 43 of Set 1 | payo
# Processing Record 44 of Set 1 | muzhi
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | meulaboh
# Processing Record 4 of Set 2 | guasdualito
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | fenyi
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | barra do garcas
# Processing Record 9 of Set 2 | wanning
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | zgorzelec
# Processing Record 14 of Set 2 | mayumba
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | san vicente
# Processing Record 17 of Set 2 | jimenez
# Processing Record 18 of Set 2 | khovu-aksy
# Processing Record 19 of Set 2 | dhangadhi
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | alot
# Processing Record 22 of Set 2 | beloha
# Processing Record 23 of Set 2 | ferme-neuve
# Processing Record 24 of Set 2 | sambava
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | asfi
# Processing Record 30 of Set 2 | praia da vitoria
# Processing Record 31 of Set 2 | beringovskiy
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | mitzic
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | richards bay
# Processing Record 37 of Set 2 | dunedin
# Processing Record 38 of Set 2 | nelson
# Processing Record 39 of Set 2 | kabac
# Processing Record 40 of Set 2 | shitkino
# Processing Record 41 of Set 2 | necochea
# Processing Record 42 of Set 2 | bosaso
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | san carlos de bariloche
# Processing Record 48 of Set 2 | tateyama
# Processing Record 49 of Set 2 | yar-sale
# Processing Record 50 of Set 2 | kruisfontein
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | stephenville
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | kinablangan
# Processing Record 7 of Set 3 | afua
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | sao jose da coroa grande
# Processing Record 10 of Set 3 | colac
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | myanaung
# Processing Record 13 of Set 3 | chara
# Processing Record 14 of Set 3 | breytovo
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | ilo
# Processing Record 17 of Set 3 | medicine hat
# Processing Record 18 of Set 3 | bereda
# Processing Record 19 of Set 3 | inuvik
# Processing Record 20 of Set 3 | pasni
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | saskylakh
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | pochutla
# Processing Record 25 of Set 3 | terrace
# Processing Record 26 of Set 3 | bilma
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | kaniama
# Processing Record 30 of Set 3 | kondopoga
# Processing Record 31 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 3 | semey
# Processing Record 33 of Set 3 | sao filipe
# Processing Record 34 of Set 3 | peniche
# Processing Record 35 of Set 3 | harper
# Processing Record 36 of Set 3 | bathsheba
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | kilindoni
# Processing Record 39 of Set 3 | watsa
# Processing Record 40 of Set 3 | gaborone
# Processing Record 41 of Set 3 | fereydunshahr
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | ribeira grande
# Processing Record 44 of Set 3 | soyo
# Processing Record 45 of Set 3 | olinda
# Processing Record 46 of Set 3 | schruns
# Processing Record 47 of Set 3 | beecher
# Processing Record 48 of Set 3 | yellowknife
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | sao joao da barra
# Processing Record 1 of Set 4 | havre-saint-pierre
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | cooma
# Processing Record 4 of Set 4 | luwuk
# Processing Record 5 of Set 4 | nuevitas
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | coahuayana
# Processing Record 8 of Set 4 | dikson
# Processing Record 9 of Set 4 | ponta delgada
# Processing Record 10 of Set 4 | pijijiapan
# Processing Record 11 of Set 4 | carbonia
# Processing Record 12 of Set 4 | pomoryany
# Processing Record 13 of Set 4 | tsiroanomandidy
# Processing Record 14 of Set 4 | dingle
# Processing Record 15 of Set 4 | iquitos
# Processing Record 16 of Set 4 | chuy
# Processing Record 17 of Set 4 | gairatganj
# Processing Record 18 of Set 4 | port-cartier
# Processing Record 19 of Set 4 | angra
# City not found. Skipping...
# Processing Record 20 of Set 4 | paita
# Processing Record 21 of Set 4 | phumi samraong
# City not found. Skipping...
# Processing Record 22 of Set 4 | kapaa
# Processing Record 23 of Set 4 | acapulco
# Processing Record 24 of Set 4 | keti bandar
# Processing Record 25 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 4 | hamilton
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | te anau
# Processing Record 29 of Set 4 | banjar
# Processing Record 30 of Set 4 | nhulunbuy
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | lerwick
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | airai
# Processing Record 35 of Set 4 | vao
# Processing Record 36 of Set 4 | husavik
# Processing Record 37 of Set 4 | solnechnyy
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | fort nelson
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 4 | kaeo
# Processing Record 43 of Set 4 | resistencia
# Processing Record 44 of Set 4 | batagay-alyta
# Processing Record 45 of Set 4 | fare
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | quatre cocos
# Processing Record 49 of Set 4 | sulmona
# Processing Record 50 of Set 4 | deputatskiy
# Processing Record 1 of Set 5 | vilhena
# Processing Record 2 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 5 | valleyview
# Processing Record 4 of Set 5 | yabrud
# Processing Record 5 of Set 5 | lhokseumawe
# Processing Record 6 of Set 5 | minsk
# Processing Record 7 of Set 5 | kyzyl-mazhalyk
# Processing Record 8 of Set 5 | havelock
# Processing Record 9 of Set 5 | garowe
# Processing Record 10 of Set 5 | kishanpur
# Processing Record 11 of Set 5 | mehamn
# Processing Record 12 of Set 5 | east london
# Processing Record 13 of Set 5 | san
# Processing Record 14 of Set 5 | ilulissat
# Processing Record 15 of Set 5 | ghanzi
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | ak-dovurak
# Processing Record 18 of Set 5 | ishigaki
# Processing Record 19 of Set 5 | luderitz
# Processing Record 20 of Set 5 | hun
# Processing Record 21 of Set 5 | gberia fotombu
# Processing Record 22 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 5 | katobu
# Processing Record 24 of Set 5 | kinna
# Processing Record 25 of Set 5 | tiznit
# Processing Record 26 of Set 5 | chute-aux-outardes
# Processing Record 27 of Set 5 | mackenzie
# Processing Record 28 of Set 5 | fereydun kenar
# Processing Record 29 of Set 5 | glinka
# Processing Record 30 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 5 | palana
# Processing Record 32 of Set 5 | thompson
# Processing Record 33 of Set 5 | huilong
# Processing Record 34 of Set 5 | andenes
# Processing Record 35 of Set 5 | tezu
# Processing Record 36 of Set 5 | nome
# Processing Record 37 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 5 | santa barbara
# Processing Record 39 of Set 5 | mogok
# Processing Record 40 of Set 5 | mauganj
# Processing Record 41 of Set 5 | arraial do cabo
# Processing Record 42 of Set 5 | warwick
# Processing Record 43 of Set 5 | norrtalje
# Processing Record 44 of Set 5 | puerto escondido
# Processing Record 45 of Set 5 | yarada
# Processing Record 46 of Set 5 | launceston
# Processing Record 47 of Set 5 | charters towers
# Processing Record 48 of Set 5 | vredendal
# Processing Record 49 of Set 5 | maniitsoq
# Processing Record 50 of Set 5 | egvekinot
# Processing Record 1 of Set 6 | jalu
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 6 | sao paulo de olivenca
# Processing Record 5 of Set 6 | port hardy
# Processing Record 6 of Set 6 | trairi
# Processing Record 7 of Set 6 | marsa matruh
# Processing Record 8 of Set 6 | celestun
# Processing Record 9 of Set 6 | hervey bay
# Processing Record 10 of Set 6 | cockburn town
# Processing Record 11 of Set 6 | tolga
# Processing Record 12 of Set 6 | drinovci
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | alice springs
# Processing Record 15 of Set 6 | camacha
# Processing Record 16 of Set 6 | san andres
# Processing Record 17 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | mgandu
# Processing Record 20 of Set 6 | methoni
# Processing Record 21 of Set 6 | lavrentiya
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | sergeyevka
# Processing Record 24 of Set 6 | north bend
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | esperance
# Processing Record 27 of Set 6 | byron bay
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | conceicao do araguaia
# Processing Record 30 of Set 6 | gornopravdinsk
# Processing Record 31 of Set 6 | kokopo
# Processing Record 32 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 6 | christchurch
# Processing Record 34 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 6 | mount gambier
# Processing Record 36 of Set 6 | astana
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | pervomayskiy
# Processing Record 39 of Set 6 | jumla
# Processing Record 40 of Set 6 | bubaque
# Processing Record 41 of Set 6 | hauterive
# Processing Record 42 of Set 6 | kota tinggi
# Processing Record 43 of Set 6 | diffa
# Processing Record 44 of Set 6 | moose factory
# Processing Record 45 of Set 6 | mayo
# Processing Record 46 of Set 6 | aranos
# Processing Record 47 of Set 6 | tuktoyaktuk
# Processing Record 48 of Set 6 | farmington
# Processing Record 49 of Set 6 | matamoros
# Processing Record 50 of Set 6 | parkes
# Processing Record 1 of Set 7 | porto novo
# Processing Record 2 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 7 | agucadoura
# Processing Record 4 of Set 7 | elko
# Processing Record 5 of Set 7 | lamar
# Processing Record 6 of Set 7 | labuhan
# Processing Record 7 of Set 7 | mathathane
# Processing Record 8 of Set 7 | sinnar
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | monte santo
# Processing Record 11 of Set 7 | champasak
# Processing Record 12 of Set 7 | vicuna
# Processing Record 13 of Set 7 | shimoda
# Processing Record 14 of Set 7 | umm kaddadah
# Processing Record 15 of Set 7 | haines junction
# Processing Record 16 of Set 7 | zyryanka
# Processing Record 17 of Set 7 | yakeshi
# Processing Record 18 of Set 7 | iberia
# Processing Record 19 of Set 7 | hobyo
# Processing Record 20 of Set 7 | mlonggo
# Processing Record 21 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 7 | tual
# Processing Record 23 of Set 7 | constitucion
# Processing Record 24 of Set 7 | paragominas
# Processing Record 25 of Set 7 | karratha
# Processing Record 26 of Set 7 | anadyr
# Processing Record 27 of Set 7 | mogadishu
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | punta alta
# Processing Record 30 of Set 7 | cabo san lucas
# Processing Record 31 of Set 7 | watertown
# Processing Record 32 of Set 7 | oranjestad
# Processing Record 33 of Set 7 | dwarka
# Processing Record 34 of Set 7 | ust-nera
# Processing Record 35 of Set 7 | ketchikan
# Processing Record 36 of Set 7 | trincomalee
# Processing Record 37 of Set 7 | leh
# Processing Record 38 of Set 7 | coihaique
# Processing Record 39 of Set 7 | pemangkat
# Processing Record 40 of Set 7 | lock haven
# Processing Record 41 of Set 7 | lloydminster
# Processing Record 42 of Set 7 | carutapera
# Processing Record 43 of Set 7 | lafia
# Processing Record 44 of Set 7 | terrace bay
# Processing Record 45 of Set 7 | ucluelet
# Processing Record 46 of Set 7 | hay river
# Processing Record 47 of Set 7 | price
# Processing Record 48 of Set 7 | marystown
# Processing Record 49 of Set 7 | grand-santi
# Processing Record 50 of Set 7 | fier
# Processing Record 1 of Set 8 | avera
# Processing Record 2 of Set 8 | heihe
# Processing Record 3 of Set 8 | acarau
# Processing Record 4 of Set 8 | mangrol
# Processing Record 5 of Set 8 | khatanga
# Processing Record 6 of Set 8 | beroroha
# Processing Record 7 of Set 8 | roald
# Processing Record 8 of Set 8 | berlevag
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 8 | codrington
# Processing Record 12 of Set 8 | ust-kuyga
# Processing Record 13 of Set 8 | huarmey
# Processing Record 14 of Set 8 | beira
# Processing Record 15 of Set 8 | alamosa
# Processing Record 16 of Set 8 | orlik
# Processing Record 17 of Set 8 | caravelas
# Processing Record 18 of Set 8 | sisimiut
# Processing Record 19 of Set 8 | half moon bay
# Processing Record 20 of Set 8 | shubarshi
# Processing Record 21 of Set 8 | arlit
# Processing Record 22 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 23 of Set 8 | sillamae
# Processing Record 24 of Set 8 | mega
# Processing Record 25 of Set 8 | tommot
# Processing Record 26 of Set 8 | kavieng
# Processing Record 27 of Set 8 | jertih
# Processing Record 28 of Set 8 | gravdal
# Processing Record 29 of Set 8 | statesboro
# Processing Record 30 of Set 8 | igarka
# Processing Record 31 of Set 8 | gilgit
# Processing Record 32 of Set 8 | iqaluit
# Processing Record 33 of Set 8 | katherine
# Processing Record 34 of Set 8 | talnakh
# Processing Record 35 of Set 8 | padureni
# City not found. Skipping...
# Processing Record 36 of Set 8 | banda aceh
# Processing Record 37 of Set 8 | chelmza
# Processing Record 38 of Set 8 | iralaya
# Processing Record 39 of Set 8 | cananeia
# Processing Record 40 of Set 8 | chhuikhadan
# Processing Record 41 of Set 8 | chokurdakh
# Processing Record 42 of Set 8 | cayenne
# Processing Record 43 of Set 8 | okhotsk
# Processing Record 44 of Set 8 | samarai
# Processing Record 45 of Set 8 | santa cruz
# Processing Record 46 of Set 8 | hofn
# Processing Record 47 of Set 8 | ojhar
# Processing Record 48 of Set 8 | kharp
# Processing Record 49 of Set 8 | burns lake
# Processing Record 50 of Set 8 | tondano
# Processing Record 1 of Set 9 | acajutla
# Processing Record 2 of Set 9 | matay
# Processing Record 3 of Set 9 | patacamaya
# Processing Record 4 of Set 9 | horn lake
# Processing Record 5 of Set 9 | west wendover
# Processing Record 6 of Set 9 | songling
# Processing Record 7 of Set 9 | key west
# Processing Record 8 of Set 9 | ixtapa
# Processing Record 9 of Set 9 | mercedes
# Processing Record 10 of Set 9 | olafsvik
# Processing Record 11 of Set 9 | verkhnevilyuysk
# Processing Record 12 of Set 9 | banswada
# Processing Record 13 of Set 9 | cortez
# Processing Record 14 of Set 9 | vardo
# Processing Record 15 of Set 9 | atasu
# Processing Record 16 of Set 9 | masallatah
# Processing Record 17 of Set 9 | savannah bight
# Processing Record 18 of Set 9 | cam ranh
# Processing Record 19 of Set 9 | corinto
# Processing Record 20 of Set 9 | maceio
# Processing Record 21 of Set 9 | shaoxing
# Processing Record 22 of Set 9 | champerico
# Processing Record 23 of Set 9 | ornskoldsvik
# Processing Record 24 of Set 9 | ewa beach
# Processing Record 25 of Set 9 | myskhako
# Processing Record 26 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 9 | bunia
# Processing Record 28 of Set 9 | arkhangelos
# City not found. Skipping...
# Processing Record 29 of Set 9 | saint anthony
# Processing Record 30 of Set 9 | kushiro
# Processing Record 31 of Set 9 | fortuna
# Processing Record 32 of Set 9 | dabat
# Processing Record 33 of Set 9 | shubarkuduk
# Processing Record 34 of Set 9 | port blair
# Processing Record 35 of Set 9 | svetlogorsk
# Processing Record 36 of Set 9 | flin flon
# Processing Record 37 of Set 9 | askiz
# Processing Record 38 of Set 9 | dalbandin
# Processing Record 39 of Set 9 | ganzhou
# Processing Record 40 of Set 9 | bonavista
# Processing Record 41 of Set 9 | alofi
# Processing Record 42 of Set 9 | henties bay
# Processing Record 43 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 9 | kavaratti
# Processing Record 45 of Set 9 | san juan
# Processing Record 46 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 9 | culpeper
# Processing Record 48 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 9 | novouzensk
# Processing Record 50 of Set 9 | santiago del estero
# Processing Record 1 of Set 10 | katsuura
# Processing Record 2 of Set 10 | usvyaty
# Processing Record 3 of Set 10 | sao miguel do araguaia
# Processing Record 4 of Set 10 | solenzo
# Processing Record 5 of Set 10 | namatanai
# Processing Record 6 of Set 10 | catamarca
# Processing Record 7 of Set 10 | yokote
# Processing Record 8 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 9 of Set 10 | codajas
# Processing Record 10 of Set 10 | sibiti
# Processing Record 11 of Set 10 | amahai
# Processing Record 12 of Set 10 | coquimbo
# Processing Record 13 of Set 10 | tiarei
# Processing Record 14 of Set 10 | goulburn
# Processing Record 15 of Set 10 | ovalle
# Processing Record 16 of Set 10 | miquelon
# Processing Record 17 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 10 | lesosibirsk
# Processing Record 19 of Set 10 | vila franca do campo
# Processing Record 20 of Set 10 | kiunga
# Processing Record 21 of Set 10 | leningradskiy
# Processing Record 22 of Set 10 | gorontalo
# Processing Record 23 of Set 10 | menongue
# Processing Record 24 of Set 10 | hudiksvall
# Processing Record 25 of Set 10 | kununurra
# Processing Record 26 of Set 10 | klyuchi
# Processing Record 27 of Set 10 | amga
# Processing Record 28 of Set 10 | balikpapan
# Processing Record 29 of Set 10 | micheweni
# Processing Record 30 of Set 10 | atbasar
# Processing Record 31 of Set 10 | lauterbach
# Processing Record 32 of Set 10 | baykit
# Processing Record 33 of Set 10 | klaksvik
# Processing Record 34 of Set 10 | comodoro rivadavia
# Processing Record 35 of Set 10 | glencoe
# Processing Record 36 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 10 | coaticook
# Processing Record 38 of Set 10 | santa cruz del sur
# Processing Record 39 of Set 10 | pinega
# Processing Record 40 of Set 10 | urumqi
# Processing Record 41 of Set 10 | itaqui
# Processing Record 42 of Set 10 | nemuro
# Processing Record 43 of Set 10 | naujamiestis
# Processing Record 44 of Set 10 | cao bang
# Processing Record 45 of Set 10 | panaba
# Processing Record 46 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 10 | puerto carreno
# Processing Record 48 of Set 10 | vernon
# Processing Record 49 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 10 | elizabeth city
# Processing Record 1 of Set 11 | cap malheureux
# Processing Record 2 of Set 11 | hanzhong
# Processing Record 3 of Set 11 | xining
# Processing Record 4 of Set 11 | kapoeta
# Processing Record 5 of Set 11 | port lincoln
# Processing Record 6 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 11 | shiojiri
# Processing Record 8 of Set 11 | poum
# Processing Record 9 of Set 11 | sembe
# Processing Record 10 of Set 11 | puerto palomas
# Processing Record 11 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 11 | kyaikkami
# Processing Record 13 of Set 11 | riyadh
# Processing Record 14 of Set 11 | grand gaube
# Processing Record 15 of Set 11 | juneau
# Processing Record 16 of Set 11 | general pico
# Processing Record 17 of Set 11 | saint-georges
# Processing Record 18 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 11 | zheleznodorozhnyy
# Processing Record 20 of Set 11 | izhma
# Processing Record 21 of Set 11 | alugan
# Processing Record 22 of Set 11 | sarankhola
# Processing Record 23 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 25 of Set 11 | olyka
# Processing Record 26 of Set 11 | faanui
# Processing Record 27 of Set 11 | la libertad
# Processing Record 28 of Set 11 | santa marta
# Processing Record 29 of Set 11 | sabha
# Processing Record 30 of Set 11 | bonoua
# Processing Record 31 of Set 11 | leon valley
# Processing Record 32 of Set 11 | lorengau
# Processing Record 33 of Set 11 | kahului
# Processing Record 34 of Set 11 | healesville
# Processing Record 35 of Set 11 | helsinki
# Processing Record 36 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 11 | sayyan
# Processing Record 38 of Set 11 | vaasa
# Processing Record 39 of Set 11 | bambanglipuro
# Processing Record 40 of Set 11 | keta
# Processing Record 41 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 42 of Set 11 | bara
# Processing Record 43 of Set 11 | guerrero negro
# Processing Record 44 of Set 11 | scottsbluff
# Processing Record 45 of Set 11 | motygino
# Processing Record 46 of Set 11 | owando
# Processing Record 47 of Set 11 | san patricio
# Processing Record 48 of Set 11 | beidao
# Processing Record 49 of Set 11 | petropavlovskoye
# Processing Record 50 of Set 11 | springbok
# Processing Record 1 of Set 12 | havoysund
# Processing Record 2 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 3 of Set 12 | luz
# Processing Record 4 of Set 12 | asau
# Processing Record 5 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 12 | margate
# Processing Record 7 of Set 12 | canico
# Processing Record 8 of Set 12 | yulara
# Processing Record 9 of Set 12 | presidencia roque saenz pena
# Processing Record 10 of Set 12 | sioux lookout
# Processing Record 11 of Set 12 | wakema
# Processing Record 12 of Set 12 | sao francisco
# Processing Record 13 of Set 12 | hovd
# Processing Record 14 of Set 12 | parthenay
# Processing Record 15 of Set 12 | tura
# Processing Record 16 of Set 12 | tanakpur
# Processing Record 17 of Set 12 | faya
# Processing Record 18 of Set 12 | la mata
# Processing Record 19 of Set 12 | formosa
# Processing Record 20 of Set 12 | saldanha
# Processing Record 21 of Set 12 | chittur
# Processing Record 22 of Set 12 | pindobacu
# Processing Record 23 of Set 12 | aktau
# Processing Record 24 of Set 12 | troitsko-pechorsk
# Processing Record 25 of Set 12 | aripuana
# Processing Record 26 of Set 12 | naze
# Processing Record 27 of Set 12 | butterworth
# Processing Record 28 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 12 | adre
# Processing Record 30 of Set 12 | santa rosalia
# Processing Record 31 of Set 12 | lata
# Processing Record 32 of Set 12 | port moresby
# Processing Record 33 of Set 12 | teguldet
# Processing Record 34 of Set 12 | northam
# Processing Record 35 of Set 12 | san cristobal
# Processing Record 36 of Set 12 | kokkola
# Processing Record 37 of Set 12 | mitchell
# Processing Record 38 of Set 12 | xiongzhou
# Processing Record 39 of Set 12 | grand-lahou
# Processing Record 40 of Set 12 | ciudad bolivar
# Processing Record 41 of Set 12 | ginir
# Processing Record 42 of Set 12 | millinocket
# Processing Record 43 of Set 12 | prieska
# Processing Record 44 of Set 12 | aras
# Processing Record 45 of Set 12 | tuban
# Processing Record 46 of Set 12 | esil
# Processing Record 47 of Set 12 | gallup
# Processing Record 48 of Set 12 | melilla
# Processing Record 49 of Set 12 | kanganpur
# Processing Record 50 of Set 12 | yarega
# Processing Record 1 of Set 13 | makakilo city
# Processing Record 2 of Set 13 | newport
# Processing Record 3 of Set 13 | salalah
# Processing Record 4 of Set 13 | ibiruba
# Processing Record 5 of Set 13 | andijon
# Processing Record 6 of Set 13 | pacific grove
# Processing Record 7 of Set 13 | sabana de torres
# Processing Record 8 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 13 | abu dhabi
# Processing Record 10 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 13 | isangel
# Processing Record 12 of Set 13 | sorong
# Processing Record 13 of Set 13 | omboue
# Processing Record 14 of Set 13 | chapais
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 13 | clinton
# Processing Record 17 of Set 13 | obidos
# Processing Record 18 of Set 13 | carndonagh
# Processing Record 19 of Set 13 | pangnirtung
# Processing Record 20 of Set 13 | kovdor
# Processing Record 21 of Set 13 | soc trang
# Processing Record 22 of Set 13 | bend
# Processing Record 23 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 13 | yaan
# Processing Record 25 of Set 13 | redcar
# Processing Record 26 of Set 13 | sibulao
# Processing Record 27 of Set 13 | kijang
# Processing Record 28 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 13 | zhuhai
# Processing Record 30 of Set 13 | skjervoy
# Processing Record 31 of Set 13 | stromness
# Processing Record 32 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 13 | denia
# Processing Record 34 of Set 13 | yeppoon
# Processing Record 35 of Set 13 | port hedland
# Processing Record 36 of Set 13 | naica
# Processing Record 37 of Set 13 | kirensk
# Processing Record 38 of Set 13 | hermosillo
# Processing Record 39 of Set 13 | young
# Processing Record 40 of Set 13 | tabuny
# Processing Record 41 of Set 13 | college
# Processing Record 42 of Set 13 | nkhotakota
# Processing Record 43 of Set 13 | malakal
# Processing Record 44 of Set 13 | kidal
# Processing Record 45 of Set 13 | polovinnoye
# Processing Record 46 of Set 13 | pitimbu
# Processing Record 47 of Set 13 | belyy yar
# Processing Record 48 of Set 13 | hambantota
# Processing Record 49 of Set 13 | gillette
# Processing Record 50 of Set 13 | opuwo
# Processing Record 1 of Set 14 | mackay
# Processing Record 2 of Set 14 | port-gentil
# Processing Record 3 of Set 14 | vila
# Processing Record 4 of Set 14 | wahpeton
# Processing Record 5 of Set 14 | kenai
# Processing Record 6 of Set 14 | pangai
# Processing Record 7 of Set 14 | belmonte
# Processing Record 8 of Set 14 | aksarka
# Processing Record 9 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 14 | kang
# Processing Record 11 of Set 14 | lar
# Processing Record 12 of Set 14 | west plains
# Processing Record 13 of Set 14 | abu road
# Processing Record 14 of Set 14 | ayan
# Processing Record 15 of Set 14 | pavlodar
# Processing Record 16 of Set 14 | keningau
# Processing Record 17 of Set 14 | komsomolskiy
# Processing Record 18 of Set 14 | coldstream
# Processing Record 19 of Set 14 | brae
# Processing Record 20 of Set 14 | yerbogachen
# Processing Record 21 of Set 14 | smoky lake
# Processing Record 22 of Set 14 | mareeba
# Processing Record 23 of Set 14 | nouadhibou
# Processing Record 24 of Set 14 | grindavik
# Processing Record 25 of Set 14 | nyagan
# Processing Record 26 of Set 14 | ha tinh
# Processing Record 27 of Set 14 | rongai
# Processing Record 28 of Set 14 | salto del guaira
# Processing Record 29 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 14 | tefe
# Processing Record 31 of Set 14 | vaitape
# Processing Record 32 of Set 14 | joshimath
# Processing Record 33 of Set 14 | sri aman
# Processing Record 34 of Set 14 | saint-pierre
# Processing Record 35 of Set 14 | lumberton
# Processing Record 36 of Set 14 | cayambe
# Processing Record 37 of Set 14 | viedma
# Processing Record 38 of Set 14 | flinders
# Processing Record 39 of Set 14 | gamba
# Processing Record 40 of Set 14 | toora-khem
# Processing Record 41 of Set 14 | mandan
# Processing Record 42 of Set 14 | san blas
# Processing Record 43 of Set 14 | apricena
# Processing Record 44 of Set 14 | jibuti
# Processing Record 45 of Set 14 | unity
# Processing Record 46 of Set 14 | edea
# Processing Record 47 of Set 14 | yagodnoye
# Processing Record 48 of Set 14 | maun
# Processing Record 49 of Set 14 | yanam
# Processing Record 50 of Set 14 | yumen
# Processing Record 1 of Set 15 | tevaitoa
# Processing Record 2 of Set 15 | srednekolymsk
# Processing Record 3 of Set 15 | gao
# Processing Record 4 of Set 15 | santo domingo
# Processing Record 5 of Set 15 | ocampo
# Processing Record 6 of Set 15 | dicabisagan
# Processing Record 7 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 8 of Set 15 | gazli
# Processing Record 9 of Set 15 | monrovia
# Processing Record 10 of Set 15 | nizhnevartovsk
# Processing Record 11 of Set 15 | piltene
# Processing Record 12 of Set 15 | xichang
# Processing Record 13 of Set 15 | hammerfest
# Processing Record 14 of Set 15 | inta
# Processing Record 15 of Set 15 | kemijarvi
# Processing Record 16 of Set 15 | saint-francois
# Processing Record 17 of Set 15 | kaka
# Processing Record 18 of Set 15 | san francisco del mar
# Processing Record 19 of Set 15 | sorland
# Processing Record 20 of Set 15 | ontario
# Processing Record 21 of Set 15 | liwale
# Processing Record 22 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 15 | new richmond
# Processing Record 24 of Set 15 | los llanos de aridane
# Processing Record 25 of Set 15 | oliver
# Processing Record 26 of Set 15 | neiafu
# Processing Record 27 of Set 15 | chumikan
# Processing Record 28 of Set 15 | witu
# Processing Record 29 of Set 15 | hanyang
# Processing Record 30 of Set 15 | maragogi
# Processing Record 31 of Set 15 | san quintin
# Processing Record 32 of Set 15 | altay
# Processing Record 33 of Set 15 | poronaysk
# Processing Record 34 of Set 15 | sokolo
# Processing Record 35 of Set 15 | omsukchan
# Processing Record 36 of Set 15 | ust-ilimsk
# Processing Record 37 of Set 15 | hit
# Processing Record 38 of Set 15 | vilyuysk
# Processing Record 39 of Set 15 | rovenki
# Processing Record 40 of Set 15 | oum hadjer
# Processing Record 41 of Set 15 | dudinka
# Processing Record 42 of Set 15 | sao domingos
# Processing Record 43 of Set 15 | phan thiet
# Processing Record 44 of Set 15 | hashtrud
# Processing Record 45 of Set 15 | camopi
# Processing Record 46 of Set 15 | puerto madero
# Processing Record 47 of Set 15 | severomuysk
# Processing Record 48 of Set 15 | karnobat
# Processing Record 49 of Set 15 | oksfjord
# Processing Record 50 of Set 15 | gubkinskiy
# Processing Record 1 of Set 16 | sindhnur
# Processing Record 2 of Set 16 | oussouye
# Processing Record 3 of Set 16 | vastervik
# City not found. Skipping...
# Processing Record 4 of Set 16 | bernalillo
# Processing Record 5 of Set 16 | gourcy
# Processing Record 6 of Set 16 | marawi
# Processing Record 7 of Set 16 | kirkwall
# Processing Record 8 of Set 16 | amancio
# City not found. Skipping...
# Processing Record 9 of Set 16 | itoman
# Processing Record 10 of Set 16 | whitehorse
# Processing Record 11 of Set 16 | urfa
# City not found. Skipping...
# Processing Record 12 of Set 16 | danane
# Processing Record 13 of Set 16 | macamic
# Processing Record 14 of Set 16 | balykshi
# Processing Record 15 of Set 16 | gat
# Processing Record 16 of Set 16 | lesnoye
# Processing Record 17 of Set 16 | skelleftea
# Processing Record 18 of Set 16 | sungai besar
# Processing Record 19 of Set 16 | mangan
# Processing Record 20 of Set 16 | raudeberg
# Processing Record 21 of Set 16 | ust-maya
# Processing Record 22 of Set 16 | karimpur
# Processing Record 23 of Set 16 | kalmunai
# Processing Record 24 of Set 16 | saint-joseph
# Processing Record 25 of Set 16 | aizawl
# Processing Record 26 of Set 16 | umm bab
# Processing Record 27 of Set 16 | norman wells
# Processing Record 28 of Set 16 | murray bridge
# Processing Record 29 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 16 | benito juarez
# Processing Record 31 of Set 16 | capoterra
# Processing Record 32 of Set 16 | oktyabrskiy
# -
# Data Retrieval Complete
# -

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 718

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                    Ahipara      NZ -35.1667  173.1667     73.94        59
# 1                 Kaitangata      NZ -46.2817  169.8464     69.15        61
# 2                  Pringsewu      ID  -5.3582  104.9744     71.58        89
# 3             Port Elizabeth      ZA -33.9180   25.5701     68.29        83
# 4  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     12.79        57
# 5                 Nikolskoye      RU  59.7035   30.7861     28.29        95
# 6                     Albany      US  42.6001  -73.9662     27.03        70
# 7                     Labuan      MY   5.2767  115.2417     77.36        94
# 8                  Busselton      AU -33.6500  115.3333     56.57        63
# 9                  Boa Vista      BR   2.8197  -60.6733     80.58        74
#
#    Cloudiness  Wind Speed Current Description
# 0           0        2.42           clear sky
# 1          16        5.39          few clouds
# 2          99        2.24          light rain
# 3          40       20.71    scattered clouds
# 4           0       11.18           clear sky
# 5         100        7.16     overcast clouds
# 6          47        5.01    scattered clouds
# 7          40        0.00    scattered clouds
# 8           0       11.81           clear sky
# 9          40       10.36    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                    Ahipara      NZ -35.1667  173.1667     73.94        59
# 1                 Kaitangata      NZ -46.2817  169.8464     69.15        61
# 2                  Pringsewu      ID  -5.3582  104.9744     71.58        89
# 3             Port Elizabeth      ZA -33.9180   25.5701     68.29        83
# 4  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     12.79        57
# 5                 Nikolskoye      RU  59.7035   30.7861     28.29        95
# 6                     Albany      US  42.6001  -73.9662     27.03        70
# 7                     Labuan      MY   5.2767  115.2417     77.36        94
# 8                  Busselton      AU -33.6500  115.3333     56.57        63
# 9                  Boa Vista      BR   2.8197  -60.6733     80.58        74
#
#    Cloudiness  Wind Speed Current Description
# 0           0        2.42           clear sky
# 1          16        5.39          few clouds
# 2          99        2.24          light rain
# 3          40       20.71    scattered clouds
# 4           0       11.18           clear sky
# 5         100        7.16     overcast clouds
# 6          47        5.01    scattered clouds
# 7          40        0.00    scattered clouds
# 8           0       11.81           clear sky
# 9          40       10.36    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City_ID")
