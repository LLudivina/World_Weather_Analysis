# %%
# Import initial libraries
#NumPy module is a numerical mathematics library that can be used to make arrays or matrices of numbers.
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#The zip object packs each pair of lats and lngs having the same index in 
#their respective array into a tuple. If there are 1,500 latitudes and 
#longitudes, there will be 1,500 tuples of paired latitudes and longitudes,
#where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests
import json

# Import the OpenWeatherMap's API key
from config import weather_api_key

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Assemble the OpenWeatherMap's API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_url = url + "&q=" + "Poway"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -117.0359, 'lat': 32.9628},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 51.26,
#   'feels_like': 50.22,
#   'temp_min': 47.84,
#   'temp_max': 54,
#   'pressure': 1016,
#   'humidity': 88},
#  'visibility': 10000,
#  'wind': {'speed': 3.44, 'deg': 110},
#  'clouds': {'all': 100},
#  'dt': 1672728445,
#  'sys': {'type': 2,
#   'id': 2016735,
#   'country': 'US',
#   'sunrise': 1672671069,
#   'sunset': 1672707167},
#  'timezone': -28800,
#  'id': 5384690,
#  'name': 'Poway',
#  'cod': 200}

# %%
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_description = city_weather["weather"][0]["description"]
print(city_lat)
print(city_lng)
print(city_max_temp)
print(city_humidity)
print(city_clouds)
print(city_wind)
print(city_country)
print(city_description)
# Out:
# 32.9628
# -117.0359
# 54
# 88
# 100
# 3.44
# US
# overcast clouds

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval")
print("-")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          })
                       
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-")
print("Data Retrieval Complete")
print("-")
# Out:
# Beginning Data Retrieval
# -
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | yaan
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | saint-francois
# Processing Record 8 of Set 1 | grevesmuhlen
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | borujerd
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | honningsvag
# Processing Record 15 of Set 1 | nova vicosa
# Processing Record 16 of Set 1 | gold coast
# Processing Record 17 of Set 1 | kontagora
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | sokoni
# Processing Record 23 of Set 1 | tezu
# Processing Record 24 of Set 1 | nelson bay
# Processing Record 25 of Set 1 | maumere
# Processing Record 26 of Set 1 | sorong
# Processing Record 27 of Set 1 | cap malheureux
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | kunming
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | pilar
# Processing Record 34 of Set 1 | karoi
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | wenling
# Processing Record 39 of Set 1 | ust-shonosha
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | jacareacanga
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 1 | moose factory
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | port lincoln
# Processing Record 49 of Set 1 | mount gambier
# Processing Record 50 of Set 1 | moussoro
# Processing Record 1 of Set 2 | chowchilla
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | beyneu
# Processing Record 4 of Set 2 | flinders
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | santo antonio do ica
# Processing Record 9 of Set 2 | praia da vitoria
# Processing Record 10 of Set 2 | betong
# Processing Record 11 of Set 2 | la victoria
# Processing Record 12 of Set 2 | kahramanmaras
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | abha
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | alihe
# Processing Record 17 of Set 2 | cayenne
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | shenjiamen
# Processing Record 20 of Set 2 | chiredzi
# Processing Record 21 of Set 2 | jalu
# Processing Record 22 of Set 2 | sao cristovao
# Processing Record 23 of Set 2 | evensk
# Processing Record 24 of Set 2 | asau
# Processing Record 25 of Set 2 | paamiut
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | labuhan
# Processing Record 30 of Set 2 | naryan-mar
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | kushiro
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | mollendo
# Processing Record 36 of Set 2 | aketi
# Processing Record 37 of Set 2 | kirakira
# Processing Record 38 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | zhanaozen
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | kamaishi
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | durango
# Processing Record 49 of Set 2 | salalah
# Processing Record 50 of Set 2 | hamilton
# Processing Record 1 of Set 3 | half moon bay
# Processing Record 2 of Set 3 | biak
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | eldorado
# Processing Record 5 of Set 3 | palmer
# Processing Record 6 of Set 3 | kazachinskoye
# Processing Record 7 of Set 3 | imbituba
# Processing Record 8 of Set 3 | svetlaya
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | tigil
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | puerto ayora
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | bogorodskoye
# Processing Record 18 of Set 3 | saldanha
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | kandrian
# Processing Record 22 of Set 3 | tabas
# Processing Record 23 of Set 3 | male
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | westport
# Processing Record 26 of Set 3 | sisimiut
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | faanui
# Processing Record 29 of Set 3 | katherine
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | hengyang
# Processing Record 32 of Set 3 | mantua
# Processing Record 33 of Set 3 | soyo
# Processing Record 34 of Set 3 | moose jaw
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | ayer itam
# City not found. Skipping...
# Processing Record 37 of Set 3 | fort nelson
# Processing Record 38 of Set 3 | siuna
# Processing Record 39 of Set 3 | bronnoysund
# Processing Record 40 of Set 3 | sanghar
# Processing Record 41 of Set 3 | nantucket
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | viedma
# Processing Record 44 of Set 3 | kepno
# Processing Record 45 of Set 3 | zyryanka
# Processing Record 46 of Set 3 | carroll
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | provideniya
# Processing Record 49 of Set 3 | acapulco
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | bilma
# Processing Record 3 of Set 4 | vardo
# Processing Record 4 of Set 4 | korgen
# Processing Record 5 of Set 4 | lavrentiya
# Processing Record 6 of Set 4 | jamestown
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | zyryanskoye
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | mayumba
# Processing Record 11 of Set 4 | sola
# Processing Record 12 of Set 4 | cockburn town
# Processing Record 13 of Set 4 | mastic beach
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | ewa beach
# Processing Record 16 of Set 4 | batesville
# Processing Record 17 of Set 4 | popondetta
# Processing Record 18 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 4 | ilulissat
# Processing Record 21 of Set 4 | ostersund
# Processing Record 22 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 4 | iwanai
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | aleksandrovka
# Processing Record 26 of Set 4 | sobolevo
# Processing Record 27 of Set 4 | manaus
# Processing Record 28 of Set 4 | iquitos
# Processing Record 29 of Set 4 | tarko-sale
# Processing Record 30 of Set 4 | kuching
# Processing Record 31 of Set 4 | nagua
# Processing Record 32 of Set 4 | litovko
# Processing Record 33 of Set 4 | carballo
# Processing Record 34 of Set 4 | naqadeh
# Processing Record 35 of Set 4 | saint-philippe
# Processing Record 36 of Set 4 | benjamin hill
# Processing Record 37 of Set 4 | lucea
# Processing Record 38 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | makakilo city
# Processing Record 41 of Set 4 | margate
# Processing Record 42 of Set 4 | port macquarie
# Processing Record 43 of Set 4 | khatanga
# Processing Record 44 of Set 4 | scarborough
# Processing Record 45 of Set 4 | port augusta
# Processing Record 46 of Set 4 | assiniboia
# Processing Record 47 of Set 4 | castro
# Processing Record 48 of Set 4 | wonthaggi
# Processing Record 49 of Set 4 | khani
# Processing Record 50 of Set 4 | bonavista
# Processing Record 1 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 5 | san carlos de bariloche
# Processing Record 3 of Set 5 | molina
# Processing Record 4 of Set 5 | axim
# Processing Record 5 of Set 5 | shambu
# Processing Record 6 of Set 5 | chernyshevskiy
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 5 | esil
# Processing Record 10 of Set 5 | thompson
# Processing Record 11 of Set 5 | zistersdorf
# Processing Record 12 of Set 5 | tucuma
# Processing Record 13 of Set 5 | kaitangata
# Processing Record 14 of Set 5 | laguna
# Processing Record 15 of Set 5 | chara
# Processing Record 16 of Set 5 | hay river
# Processing Record 17 of Set 5 | togur
# Processing Record 18 of Set 5 | pangnirtung
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | saquarema
# Processing Record 21 of Set 5 | denizli
# Processing Record 22 of Set 5 | port hardy
# Processing Record 23 of Set 5 | kalengwa
# Processing Record 24 of Set 5 | ribas do rio pardo
# Processing Record 25 of Set 5 | nova olimpia
# Processing Record 26 of Set 5 | vero beach
# Processing Record 27 of Set 5 | candawaga
# City not found. Skipping...
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | aberdeen
# Processing Record 30 of Set 5 | boyabat
# Processing Record 31 of Set 5 | mandalgovi
# Processing Record 32 of Set 5 | berdigestyakh
# Processing Record 33 of Set 5 | guadalajara
# Processing Record 34 of Set 5 | kudirkos naumiestis
# Processing Record 35 of Set 5 | rio grande
# Processing Record 36 of Set 5 | timbauba
# Processing Record 37 of Set 5 | prim decembrie
# Processing Record 38 of Set 5 | grand gaube
# Processing Record 39 of Set 5 | fairbanks
# Processing Record 40 of Set 5 | kula
# Processing Record 41 of Set 5 | bandarbeyla
# Processing Record 42 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 5 | kibala
# Processing Record 44 of Set 5 | bagdarin
# Processing Record 45 of Set 5 | linao
# Processing Record 46 of Set 5 | hambantota
# Processing Record 47 of Set 5 | prainha
# Processing Record 48 of Set 5 | yumen
# Processing Record 49 of Set 5 | trelew
# Processing Record 50 of Set 5 | huarmey
# Processing Record 1 of Set 6 | san juan bautista
# Processing Record 2 of Set 6 | pali
# Processing Record 3 of Set 6 | deputatskiy
# Processing Record 4 of Set 6 | karratha
# Processing Record 5 of Set 6 | luoyang
# Processing Record 6 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 6 | tual
# Processing Record 8 of Set 6 | shigony
# Processing Record 9 of Set 6 | bichura
# Processing Record 10 of Set 6 | ozark
# Processing Record 11 of Set 6 | chuy
# Processing Record 12 of Set 6 | morant bay
# Processing Record 13 of Set 6 | arrecife
# Processing Record 14 of Set 6 | gzhatsk
# City not found. Skipping...
# Processing Record 15 of Set 6 | manta
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 6 | nikolskoye
# Processing Record 19 of Set 6 | calvinia
# Processing Record 20 of Set 6 | gaoual
# Processing Record 21 of Set 6 | guisa
# Processing Record 22 of Set 6 | mityana
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | mormugao
# Processing Record 25 of Set 6 | batemans bay
# Processing Record 26 of Set 6 | resplendor
# Processing Record 27 of Set 6 | manzanillo
# Processing Record 28 of Set 6 | kenai
# Processing Record 29 of Set 6 | itoman
# Processing Record 30 of Set 6 | vestmannaeyjar
# Processing Record 31 of Set 6 | santo augusto
# Processing Record 32 of Set 6 | nancha
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 6 | santa cruz
# Processing Record 36 of Set 6 | itaituba
# Processing Record 37 of Set 6 | portland
# Processing Record 38 of Set 6 | mundo nuevo
# Processing Record 39 of Set 6 | smoky lake
# Processing Record 40 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | oksfjord
# Processing Record 44 of Set 6 | moranbah
# Processing Record 45 of Set 6 | rio gallegos
# Processing Record 46 of Set 6 | milkovo
# Processing Record 47 of Set 6 | bathsheba
# Processing Record 48 of Set 6 | kushmurun
# Processing Record 49 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 50 of Set 6 | jaunpur
# Processing Record 1 of Set 7 | katangli
# Processing Record 2 of Set 7 | quelimane
# Processing Record 3 of Set 7 | auki
# Processing Record 4 of Set 7 | praia
# Processing Record 5 of Set 7 | ionia
# Processing Record 6 of Set 7 | carbonia
# Processing Record 7 of Set 7 | razdolinsk
# Processing Record 8 of Set 7 | kaeo
# Processing Record 9 of Set 7 | turukhansk
# Processing Record 10 of Set 7 | san cristobal
# Processing Record 11 of Set 7 | klaksvik
# Processing Record 12 of Set 7 | alyangula
# Processing Record 13 of Set 7 | oyon
# Processing Record 14 of Set 7 | banda aceh
# Processing Record 15 of Set 7 | san quintin
# Processing Record 16 of Set 7 | jimma
# Processing Record 17 of Set 7 | tukrah
# Processing Record 18 of Set 7 | bulgan
# Processing Record 19 of Set 7 | narsaq
# Processing Record 20 of Set 7 | dalvik
# Processing Record 21 of Set 7 | waw
# Processing Record 22 of Set 7 | sechura
# Processing Record 23 of Set 7 | bose
# Processing Record 24 of Set 7 | miramar
# Processing Record 25 of Set 7 | souillac
# Processing Record 26 of Set 7 | arroio grande
# Processing Record 27 of Set 7 | feuchtwangen
# Processing Record 28 of Set 7 | bengbu
# Processing Record 29 of Set 7 | burnie
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | sovetskoye
# Processing Record 32 of Set 7 | richards bay
# Processing Record 33 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 7 | mananara
# Processing Record 35 of Set 7 | umm lajj
# Processing Record 36 of Set 7 | maceio
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | jishou
# Processing Record 39 of Set 7 | isangel
# Processing Record 40 of Set 7 | vanavara
# Processing Record 41 of Set 7 | karpogory
# Processing Record 42 of Set 7 | cabo san lucas
# Processing Record 43 of Set 7 | dickinson
# Processing Record 44 of Set 7 | palana
# Processing Record 45 of Set 7 | shache
# Processing Record 46 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 7 | shihezi
# Processing Record 48 of Set 7 | mbala
# Processing Record 49 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 7 | korla
# Processing Record 1 of Set 8 | caruray
# Processing Record 2 of Set 8 | shingu
# Processing Record 3 of Set 8 | pasighat
# Processing Record 4 of Set 8 | marzuq
# Processing Record 5 of Set 8 | yulara
# Processing Record 6 of Set 8 | tuatapere
# Processing Record 7 of Set 8 | carnarvon
# Processing Record 8 of Set 8 | ilhabela
# Processing Record 9 of Set 8 | kajaani
# Processing Record 10 of Set 8 | caravelas
# Processing Record 11 of Set 8 | tazovskiy
# Processing Record 12 of Set 8 | arlit
# Processing Record 13 of Set 8 | tiznit
# Processing Record 14 of Set 8 | sabang
# Processing Record 15 of Set 8 | kamina
# Processing Record 16 of Set 8 | pathein
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 8 | bemidji
# Processing Record 20 of Set 8 | fez
# Processing Record 21 of Set 8 | newport
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | skelleftea
# Processing Record 24 of Set 8 | pitimbu
# Processing Record 25 of Set 8 | zhigansk
# Processing Record 26 of Set 8 | alofi
# Processing Record 27 of Set 8 | pochutla
# Processing Record 28 of Set 8 | guaymango
# Processing Record 29 of Set 8 | saint-joseph
# Processing Record 30 of Set 8 | kununurra
# Processing Record 31 of Set 8 | dalhousie
# Processing Record 32 of Set 8 | kolvereid
# Processing Record 33 of Set 8 | okhotsk
# Processing Record 34 of Set 8 | ayan
# Processing Record 35 of Set 8 | severnyy
# Processing Record 36 of Set 8 | moron
# Processing Record 37 of Set 8 | itarema
# Processing Record 38 of Set 8 | mecca
# Processing Record 39 of Set 8 | jiayuguan
# Processing Record 40 of Set 8 | prince rupert
# Processing Record 41 of Set 8 | moree
# Processing Record 42 of Set 8 | baley
# Processing Record 43 of Set 8 | bonthe
# Processing Record 44 of Set 8 | kastamonu
# Processing Record 45 of Set 8 | port shepstone
# Processing Record 46 of Set 8 | pokanayevka
# City not found. Skipping...
# Processing Record 47 of Set 8 | sinnamary
# Processing Record 48 of Set 8 | bria
# Processing Record 49 of Set 8 | namibe
# Processing Record 50 of Set 8 | estevan
# Processing Record 1 of Set 9 | clovis
# Processing Record 2 of Set 9 | barcelos
# Processing Record 3 of Set 9 | dikson
# Processing Record 4 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 9 | sarkand
# Processing Record 6 of Set 9 | murgab
# Processing Record 7 of Set 9 | husavik
# Processing Record 8 of Set 9 | kavieng
# Processing Record 9 of Set 9 | vila velha
# Processing Record 10 of Set 9 | sao felix do xingu
# Processing Record 11 of Set 9 | akdepe
# Processing Record 12 of Set 9 | airai
# Processing Record 13 of Set 9 | santa rosa
# Processing Record 14 of Set 9 | tigzirt
# Processing Record 15 of Set 9 | olafsvik
# Processing Record 16 of Set 9 | dengfeng
# Processing Record 17 of Set 9 | praya
# Processing Record 18 of Set 9 | benghazi
# Processing Record 19 of Set 9 | port hawkesbury
# Processing Record 20 of Set 9 | zaozerne
# Processing Record 21 of Set 9 | sur
# Processing Record 22 of Set 9 | northam
# Processing Record 23 of Set 9 | miles city
# Processing Record 24 of Set 9 | ancud
# Processing Record 25 of Set 9 | belmonte
# Processing Record 26 of Set 9 | pitelino
# Processing Record 27 of Set 9 | novospasskoye
# Processing Record 28 of Set 9 | abu samrah
# Processing Record 29 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 9 | nicoya
# Processing Record 31 of Set 9 | minab
# Processing Record 32 of Set 9 | egvekinot
# Processing Record 33 of Set 9 | bestobe
# Processing Record 34 of Set 9 | kimbe
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | sawakin
# Processing Record 37 of Set 9 | dorado
# Processing Record 38 of Set 9 | gewane
# Processing Record 39 of Set 9 | camacha
# Processing Record 40 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 9 | longyearbyen
# Processing Record 42 of Set 9 | balao
# Processing Record 43 of Set 9 | el campo
# Processing Record 44 of Set 9 | pevek
# Processing Record 45 of Set 9 | geraldton
# Processing Record 46 of Set 9 | ouallam
# Processing Record 47 of Set 9 | xuanwu
# Processing Record 48 of Set 9 | carrickfergus
# Processing Record 49 of Set 9 | louis trichardt
# Processing Record 50 of Set 9 | sinop
# Processing Record 1 of Set 10 | ko samui
# Processing Record 2 of Set 10 | camocim
# Processing Record 3 of Set 10 | broken hill
# Processing Record 4 of Set 10 | te anau
# Processing Record 5 of Set 10 | kargasok
# Processing Record 6 of Set 10 | corner brook
# Processing Record 7 of Set 10 | gamba
# Processing Record 8 of Set 10 | vostok
# Processing Record 9 of Set 10 | brae
# Processing Record 10 of Set 10 | porbandar
# Processing Record 11 of Set 10 | puerto cabello
# Processing Record 12 of Set 10 | bafra
# Processing Record 13 of Set 10 | igarka
# Processing Record 14 of Set 10 | leshukonskoye
# Processing Record 15 of Set 10 | poum
# Processing Record 16 of Set 10 | iwaki
# Processing Record 17 of Set 10 | ambon
# Processing Record 18 of Set 10 | guerrero negro
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | russell
# Processing Record 21 of Set 10 | mancio lima
# Processing Record 22 of Set 10 | la gaulette
# City not found. Skipping...
# Processing Record 23 of Set 10 | comodoro rivadavia
# Processing Record 24 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 10 | abnub
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | avigliano
# Processing Record 28 of Set 10 | lagoa
# Processing Record 29 of Set 10 | kloulklubed
# Processing Record 30 of Set 10 | la ronge
# Processing Record 31 of Set 10 | kushikino
# Processing Record 32 of Set 10 | baicheng
# Processing Record 33 of Set 10 | port hedland
# Processing Record 34 of Set 10 | tongzi
# Processing Record 35 of Set 10 | gazion
# City not found. Skipping...
# Processing Record 36 of Set 10 | tadine
# Processing Record 37 of Set 10 | erenhot
# Processing Record 38 of Set 10 | dunmore town
# Processing Record 39 of Set 10 | lannion
# Processing Record 40 of Set 10 | vredefort
# Processing Record 41 of Set 10 | belaya gora
# Processing Record 42 of Set 10 | manggar
# Processing Record 43 of Set 10 | verkhoyansk
# Processing Record 44 of Set 10 | herat
# Processing Record 45 of Set 10 | najran
# Processing Record 46 of Set 10 | champerico
# Processing Record 47 of Set 10 | henties bay
# Processing Record 48 of Set 10 | killybegs
# Processing Record 49 of Set 10 | taitung
# Processing Record 50 of Set 10 | grande prairie
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | brigantine
# Processing Record 3 of Set 11 | constitucion
# Processing Record 4 of Set 11 | lokosovo
# Processing Record 5 of Set 11 | maragogi
# Processing Record 6 of Set 11 | aripuana
# Processing Record 7 of Set 11 | kaoma
# Processing Record 8 of Set 11 | amarante do maranhao
# Processing Record 9 of Set 11 | qaqortoq
# Processing Record 10 of Set 11 | point pleasant
# Processing Record 11 of Set 11 | ponta delgada
# Processing Record 12 of Set 11 | dunedin
# Processing Record 13 of Set 11 | saint-pierre
# Processing Record 14 of Set 11 | wajima
# Processing Record 15 of Set 11 | arawa
# Processing Record 16 of Set 11 | brookhaven
# Processing Record 17 of Set 11 | sretensk
# Processing Record 18 of Set 11 | road town
# Processing Record 19 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 11 | mujiayingzi
# Processing Record 21 of Set 11 | kompaniyivka
# Processing Record 22 of Set 11 | chimoio
# Processing Record 23 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 24 of Set 11 | dubreka
# Processing Record 25 of Set 11 | lusambo
# Processing Record 26 of Set 11 | padang
# Processing Record 27 of Set 11 | oyem
# Processing Record 28 of Set 11 | naze
# Processing Record 29 of Set 11 | bella vista
# Processing Record 30 of Set 11 | las palmas
# Processing Record 31 of Set 11 | hovd
# Processing Record 32 of Set 11 | chicama
# Processing Record 33 of Set 11 | yantikovo
# Processing Record 34 of Set 11 | tripoli
# Processing Record 35 of Set 11 | diego de almagro
# Processing Record 36 of Set 11 | kegums
# Processing Record 37 of Set 11 | mandla
# Processing Record 38 of Set 11 | mayo
# Processing Record 39 of Set 11 | siwan
# Processing Record 40 of Set 11 | kerouane
# Processing Record 41 of Set 11 | goderich
# Processing Record 42 of Set 11 | fairmont
# Processing Record 43 of Set 11 | bilibino
# Processing Record 44 of Set 11 | beaverlodge
# Processing Record 45 of Set 11 | hasaki
# Processing Record 46 of Set 11 | yar-sale
# Processing Record 47 of Set 11 | port said
# Processing Record 48 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 11 | issoire
# Processing Record 50 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 12 | labytnangi
# Processing Record 2 of Set 12 | kailua
# Processing Record 3 of Set 12 | muros
# Processing Record 4 of Set 12 | bwanga
# Processing Record 5 of Set 12 | safaga
# Processing Record 6 of Set 12 | aguimes
# Processing Record 7 of Set 12 | sorland
# Processing Record 8 of Set 12 | ixtapa
# Processing Record 9 of Set 12 | miguel pereira
# Processing Record 10 of Set 12 | aitape
# Processing Record 11 of Set 12 | awjilah
# Processing Record 12 of Set 12 | wickliffe
# Processing Record 13 of Set 12 | meulaboh
# Processing Record 14 of Set 12 | wuwei
# Processing Record 15 of Set 12 | neiafu
# Processing Record 16 of Set 12 | romitan
# Processing Record 17 of Set 12 | miraflores
# Processing Record 18 of Set 12 | laem sing
# Processing Record 19 of Set 12 | sosua
# Processing Record 20 of Set 12 | gibara
# Processing Record 21 of Set 12 | syamzha
# Processing Record 22 of Set 12 | sao filipe
# Processing Record 23 of Set 12 | raudeberg
# Processing Record 24 of Set 12 | yeniseysk
# Processing Record 25 of Set 12 | lukulu
# Processing Record 26 of Set 12 | saint george
# Processing Record 27 of Set 12 | sao caetano de odivelas
# Processing Record 28 of Set 12 | gandu
# Processing Record 29 of Set 12 | masallatah
# Processing Record 30 of Set 12 | puerto escondido
# Processing Record 31 of Set 12 | jawhar
# Processing Record 32 of Set 12 | matagami
# Processing Record 33 of Set 12 | the valley
# Processing Record 34 of Set 12 | studenicani
# City not found. Skipping...
# Processing Record 35 of Set 12 | kansanshi
# Processing Record 36 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 12 | avera
# Processing Record 38 of Set 12 | vylgort
# City not found. Skipping...
# Processing Record 39 of Set 12 | corinto
# Processing Record 40 of Set 12 | helong
# Processing Record 41 of Set 12 | langenburg
# Processing Record 42 of Set 12 | gat
# Processing Record 43 of Set 12 | rosarito
# Processing Record 44 of Set 12 | itaueira
# Processing Record 45 of Set 12 | nome
# Processing Record 46 of Set 12 | bayangol
# Processing Record 47 of Set 12 | saint-augustin
# Processing Record 48 of Set 12 | bud
# Processing Record 49 of Set 12 | kawalu
# Processing Record 50 of Set 12 | nabire
# Processing Record 1 of Set 13 | lahat
# Processing Record 2 of Set 13 | gornopravdinsk
# Processing Record 3 of Set 13 | inhambane
# Processing Record 4 of Set 13 | binga
# Processing Record 5 of Set 13 | maneromango
# Processing Record 6 of Set 13 | adrar
# Processing Record 7 of Set 13 | dzhebariki-khaya
# Processing Record 8 of Set 13 | giyani
# Processing Record 9 of Set 13 | skjervoy
# Processing Record 10 of Set 13 | dali
# Processing Record 11 of Set 13 | waspan
# Processing Record 12 of Set 13 | nizhniy kuranakh
# Processing Record 13 of Set 13 | nguruka
# Processing Record 14 of Set 13 | budaors
# Processing Record 15 of Set 13 | dudinka
# Processing Record 16 of Set 13 | batticaloa
# Processing Record 17 of Set 13 | genhe
# Processing Record 18 of Set 13 | havre-saint-pierre
# Processing Record 19 of Set 13 | thai binh
# Processing Record 20 of Set 13 | pitea
# Processing Record 21 of Set 13 | lorengau
# Processing Record 22 of Set 13 | maun
# Processing Record 23 of Set 13 | turinskaya sloboda
# Processing Record 24 of Set 13 | hohhot
# Processing Record 25 of Set 13 | kedrovyy
# Processing Record 26 of Set 13 | kysyl-syr
# Processing Record 27 of Set 13 | mamou
# Processing Record 28 of Set 13 | demyansk
# Processing Record 29 of Set 13 | kangaatsiaq
# Processing Record 30 of Set 13 | novyy urgal
# Processing Record 31 of Set 13 | sao joao da barra
# Processing Record 32 of Set 13 | sengiley
# Processing Record 33 of Set 13 | cedar city
# Processing Record 34 of Set 13 | mabaruma
# Processing Record 35 of Set 13 | saint anthony
# Processing Record 36 of Set 13 | muli
# Processing Record 37 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 13 | bubaque
# Processing Record 39 of Set 13 | kuytun
# Processing Record 40 of Set 13 | chifeng
# Processing Record 41 of Set 13 | vila franca do campo
# Processing Record 42 of Set 13 | panguipulli
# Processing Record 43 of Set 13 | crossville
# Processing Record 44 of Set 13 | porto novo
# Processing Record 45 of Set 13 | masvingo
# Processing Record 46 of Set 13 | elbrus
# Processing Record 47 of Set 13 | davila
# Processing Record 48 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 49 of Set 13 | kribi
# Processing Record 50 of Set 13 | taunggyi
# Processing Record 1 of Set 14 | wanning
# Processing Record 2 of Set 14 | bratsk
# Processing Record 3 of Set 14 | luau
# Processing Record 4 of Set 14 | touros
# Processing Record 5 of Set 14 | taloqan
# Processing Record 6 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 7 of Set 14 | namatanai
# Processing Record 8 of Set 14 | kano
# Processing Record 9 of Set 14 | zheleznodorozhnyy
# Processing Record 10 of Set 14 | uralets
# Processing Record 11 of Set 14 | shubarshi
# Processing Record 12 of Set 14 | mulchen
# Processing Record 13 of Set 14 | bloemhof
# Processing Record 14 of Set 14 | solnechnyy
# Processing Record 15 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 14 | hami
# Processing Record 17 of Set 14 | kondoa
# Processing Record 18 of Set 14 | sarangani
# Processing Record 19 of Set 14 | havelock
# Processing Record 20 of Set 14 | sergeyevka
# Processing Record 21 of Set 14 | eyl
# Processing Record 22 of Set 14 | badarpur
# Processing Record 23 of Set 14 | mossendjo
# Processing Record 24 of Set 14 | alta floresta
# Processing Record 25 of Set 14 | mikhaylovka
# Processing Record 26 of Set 14 | novouzensk
# Processing Record 27 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 29 of Set 14 | college
# Processing Record 30 of Set 14 | mango
# Processing Record 31 of Set 14 | quatre cocos
# Processing Record 32 of Set 14 | nenjiang
# Processing Record 33 of Set 14 | mao
# Processing Record 34 of Set 14 | burica
# City not found. Skipping...
# Processing Record 35 of Set 14 | turtas
# Processing Record 36 of Set 14 | ouro fino
# Processing Record 37 of Set 14 | raga
# Processing Record 38 of Set 14 | saint-georges
# Processing Record 39 of Set 14 | teruel
# Processing Record 40 of Set 14 | iskateley
# Processing Record 41 of Set 14 | cabatuan
# Processing Record 42 of Set 14 | veraval
# Processing Record 43 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 14 | aklavik
# Processing Record 45 of Set 14 | aykhal
# Processing Record 46 of Set 14 | ust-tsilma
# Processing Record 47 of Set 14 | chico
# Processing Record 48 of Set 14 | rizhao
# Processing Record 49 of Set 14 | thaba-tseka
# Processing Record 50 of Set 14 | alice springs
# Processing Record 1 of Set 15 | zhanakorgan
# Processing Record 2 of Set 15 | takoradi
# Processing Record 3 of Set 15 | sant feliu de guixols
# Processing Record 4 of Set 15 | dire dawa
# Processing Record 5 of Set 15 | termoli
# Processing Record 6 of Set 15 | port blair
# Processing Record 7 of Set 15 | marawi
# Processing Record 8 of Set 15 | iguape
# Processing Record 9 of Set 15 | dakar
# Processing Record 10 of Set 15 | kesennuma
# City not found. Skipping...
# Processing Record 11 of Set 15 | madras
# Processing Record 12 of Set 15 | thinadhoo
# Processing Record 13 of Set 15 | camapua
# Processing Record 14 of Set 15 | mosetse
# Processing Record 15 of Set 15 | rancho palos verdes
# Processing Record 16 of Set 15 | loiza
# Processing Record 17 of Set 15 | myaundzha
# Processing Record 18 of Set 15 | qasigiannguit
# Processing Record 19 of Set 15 | charters towers
# Processing Record 20 of Set 15 | haines junction
# Processing Record 21 of Set 15 | talnakh
# Processing Record 22 of Set 15 | port-gentil
# Processing Record 23 of Set 15 | falam
# Processing Record 24 of Set 15 | oriximina
# Processing Record 25 of Set 15 | zaysan
# Processing Record 26 of Set 15 | safranbolu
# Processing Record 27 of Set 15 | sao gabriel da cachoeira
# Processing Record 28 of Set 15 | north vanlaiphai
# Processing Record 29 of Set 15 | los aquijes
# Processing Record 30 of Set 15 | kudymkar
# Processing Record 31 of Set 15 | harper
# Processing Record 32 of Set 15 | nara
# Processing Record 33 of Set 15 | caluquembe
# Processing Record 34 of Set 15 | port moresby
# Processing Record 35 of Set 15 | vao
# Processing Record 36 of Set 15 | do rud
# City not found. Skipping...
# Processing Record 37 of Set 15 | itupiranga
# Processing Record 38 of Set 15 | kampot
# Processing Record 39 of Set 15 | stokmarknes
# Processing Record 40 of Set 15 | iberia
# Processing Record 41 of Set 15 | debre tabor
# Processing Record 42 of Set 15 | adeje
# Processing Record 43 of Set 15 | visnes
# Processing Record 44 of Set 15 | blagoyevo
# Processing Record 45 of Set 15 | anloga
# Processing Record 46 of Set 15 | novopokrovka
# Processing Record 47 of Set 15 | san francisco
# Processing Record 48 of Set 15 | ardakan
# Processing Record 49 of Set 15 | leeton
# Processing Record 50 of Set 15 | pafos
# Processing Record 1 of Set 16 | hailar
# Processing Record 2 of Set 16 | cooma
# Processing Record 3 of Set 16 | rundu
# Processing Record 4 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 16 | great falls
# Processing Record 6 of Set 16 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 16 | urumqi
# Processing Record 8 of Set 16 | ikongo
# Processing Record 9 of Set 16 | cuamba
# Processing Record 10 of Set 16 | bosilegrad
# Processing Record 11 of Set 16 | darnah
# Processing Record 12 of Set 16 | porto murtinho
# Processing Record 13 of Set 16 | viligili
# City not found. Skipping...
# -
# Data Retrieval Complete
# -

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 707

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bethel      US  41.3712  -73.4140     44.85        82         100
# 1          Atuona      PF  -9.8000 -139.0333     78.82        75          12
# 2         Ushuaia      AR -54.8000  -68.3000     40.66        75          75
# 3            Yaan      NG   7.3833    8.5667     75.85        29           3
# 4         Qaanaaq      GL  77.4840  -69.3632    -14.21        75           1
# 5  Saint-Francois      FR  46.4154    3.9054     40.44       100         100
# 6    Grevesmuhlen      DE  53.8667   11.1833     38.79        91           8
# 7          Torbay      CA  47.6666  -52.7314     30.27        92          75
# 8         Mataura      NZ -46.1927  168.8643     69.35        64          96
# 9        Hermanus      ZA -34.4187   19.2345     70.07        78           6
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1       21.85          few clouds
# 2        6.91       moderate rain
# 3       10.40           clear sky
# 4        5.97           clear sky
# 5        0.00                 fog
# 6       12.68           clear sky
# 7        6.91       broken clouds
# 8        3.44     overcast clouds
# 9        5.32           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bethel      US  41.3712  -73.4140     44.85        82         100
# 1          Atuona      PF  -9.8000 -139.0333     78.82        75          12
# 2         Ushuaia      AR -54.8000  -68.3000     40.66        75          75
# 3            Yaan      NG   7.3833    8.5667     75.85        29           3
# 4         Qaanaaq      GL  77.4840  -69.3632    -14.21        75           1
# 5  Saint-Francois      FR  46.4154    3.9054     40.44       100         100
# 6    Grevesmuhlen      DE  53.8667   11.1833     38.79        91           8
# 7          Torbay      CA  47.6666  -52.7314     30.27        92          75
# 8         Mataura      NZ -46.1927  168.8643     69.35        64          96
# 9        Hermanus      ZA -34.4187   19.2345     70.07        78           6
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1       21.85          few clouds
# 2        6.91       moderate rain
# 3       10.40           clear sky
# 4        5.97           clear sky
# 5        0.00                 fog
# 6       12.68           clear sky
# 7        6.91       broken clouds
# 8        3.44     overcast clouds
# 9        5.32           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City_ID")
